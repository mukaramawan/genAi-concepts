# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
import os

# %%
def get_groq_llm():
    return ChatOpenAI(
        model="openai/gpt-oss-20b",
        base_url="https://api.groq.com/openai/v1",
        api_key=os.getenv("GROQ_API_KEY"),
        temperature=0.7, max_tokens=2000
    )

llm = get_groq_llm()

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
workflow

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄',
#  'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄', 'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-aa9e-6be4-8002-b537d6270365'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:29:32.181093+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, tasks=(), interrupts=())

# %% [markdown]
# # ## Intermediate States

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄', 'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-aa9e-6be4-8002-b537d6270365'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:29:32.181093+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:29:30.693994+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='581fc5a9-26df-b2fd-f71d-9648c80331a4', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-29T05:29:30.486143+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, tasks=(PregelTask(id='823e43a4-f349-4e77-ff9e-ed4a53352bb1', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-29T05:29:30.485205+00:00', parent_config=None, tasks=(PregelTask(id='7c650d2d-e3b9-8235-dc60-65a875926799', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti break up with the lasagna?  \n\nBecause it got tired of all the “layer‑by‑layer” drama and wanted something a little more “pasta‑tively” spontaneous!',
#  'explanation': '**Why the joke works – a breakdown of the word‑play and absurdity**\n\n| Element | What it’s doing | Why it’s funny |\n|---------|-----------------|----------------|\n| **“Why did the spaghetti break up with the lasagna?”** | Sets up the classic “Why did X break up with Y'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti break up with the lasagna?  \n\nBecause it got tired of all the “layer‑by‑layer” drama and wanted something a little more “pasta‑tively” spontaneous!', 'explanation': '**Why the joke works – a breakdown of the word‑play and absurdity**\n\n| Element | What it’s doing | Why it’s funny |\n|---------|-----------------|----------------|\n| **“Why did the spaghetti break up with the lasagna?”** | Sets up the classic “Why did X break up with Y'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-9210-6000-8002-898614f88586'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:33:58.041577+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-7b93-6c3c-8001-c4a1d62ed9fc'}}, tasks=(), interrupts=())

# %% [markdown]
# # ### Time Travel
# #
# # ## we can go back to any previous node to do the execution again for debugging & changing the input as well

# %% [markdown]
# ## so let's go to the pizza example where we got the topic & we want to go back to joke generation step & further steps.
# ## In order to do that we need to grab the checkpoint id where we got the topic. We can get it from the state history.

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti break up with the lasagna?  \n\nBecause it got tired of all the “layer‑by‑layer” drama and wanted something a little more “pasta‑tively” spontaneous!', 'explanation': '**Why the joke works – a breakdown of the word‑play and absurdity**\n\n| Element | What it’s doing | Why it’s funny |\n|---------|-----------------|----------------|\n| **“Why did the spaghetti break up with the lasagna?”** | Sets up the classic “Why did X break up with Y'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-9210-6000-8002-898614f88586'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:33:58.041577+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-7b93-6c3c-8001-c4a1d62ed9fc'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti break up with the lasagna?  \n\nBecause it got tired of all the “layer‑by‑layer” drama and wanted something a little more “pasta‑tively” spontaneous!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-7b93-6c3c-8001-c4a1d62ed9fc'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:33:55.683825+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-77c5-6b0a-8000-c1cbab606ebb'}}, tasks=(PregelTask(id='5530259f-9019-bcec-7b2a-9c0eacdff553', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**Why the joke works – a breakdown of the word‑play and absurdity**\n\n| Element | What it’s doing | Why it’s funny |\n|---------|-----------------|----------------|\n| **“Why did the spaghetti break up with the lasagna?”** | Sets up the classic “Why did X break up with Y'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-77c5-6b0a-8000-c1cbab606ebb'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-29T05:33:55.284855+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-77c3-6e04-bfff-40b3e8bf87eb'}}, tasks=(PregelTask(id='ba243b3b-c587-760b-9ca9-0bff43f4de0a', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the spaghetti break up with the lasagna?  \n\nBecause it got tired of all the “layer‑by‑layer” drama and wanted something a little more “pasta‑tively” spontaneous!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e477f-77c3-6e04-bfff-40b3e8bf87eb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-29T05:33:55.284117+00:00', parent_config=None, tasks=(PregelTask(id='3ede995e-dc4b-3c44-1e0f-182f843eb1d8', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pasta'}),), interrupts=())]

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f0e4775-9a74-6778-8000-a0ba93bce9ef"}}) ## checkpoint id from pizza run where we haver the topic but we need to generate the joke
# Out:
# StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-29T05:29:30.486143+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, tasks=(PregelTask(id='823e43a4-f349-4e77-ff9e-ed4a53352bb1', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f0e4775-9a74-6778-8000-a0ba93bce9ef"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action! 🍕😄',
#  'explanation': "**Explanation of the joke**\n\n> *Why did the pizza apply for a job?  \n>  Because it wanted to get a *slice* of the action!*\n\nThis joke is a classic example of a **pun**—a play on words that relies on a double meaning. Let’s break it down:\n\n| Part of the joke | Literal meaning | Figurative / pun meaning |\n|------------------|-----------------|--------------------------|\n| **“Pizza”** | A food item made of dough, sauce, cheese, etc. | Personified as a character capable of making decisions. |\n| **“Apply for a job”** | To submit a request to work somewhere. | Indicates the pizza wants to be employed. |\n| **“Slice”** | A portion of a pizza. | Also a metaphor for “a piece” or “a share” of something. |\n| **“Slice of the action”** | A part of an exciting event or activity. | A humorous way of saying “I want to be part of what's happening.” |\n\n### How the pun works\n\n1. **Wordplay on “slice”**  \n   - In the world of pizza, a *slice* is the most common way to serve it.  \n   - In everyday speech, saying you want a *slice of the action* means you want a share of the excitement or a role in something happening.\n\n2. **Anthropomorphism**  \n   - The joke gives the pizza human-like motivations (wanting a job).  \n   - By doing so, it sets up the expectation that the pizza’s desire is a normal human desire, only to twist it with the double meaning of “slice.”\n\n3. **Humor from the unexpected twist**  \n   - The set‑up (“Why did the pizza apply for a job?”) leads the listener to expect a logical, perhaps silly answer (e.g., “Because it needed a dough‑nut”).  \n   - The punchline flips that expectation by using the dual meaning of *slice*, making the pizza’s motivation sound both literal (it wants a slice of pizza) and figurative (it wants a slice of the action).\n\n### Bottom line\n\nThe joke’s humor comes from the clever overlap between a pizza’s literal component (a slice of pizza) and the figurative phrase “slice of the action.” By giving the pizza a job‑seeking motive, the punchline turns a simple culinary term into a playful commentary on wanting to be involved in something exciting."}

# %% [markdown]
# # ## now we can see more Snapshots due to the re-execution

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action! 🍕😄', 'explanation': "**Explanation of the joke**\n\n> *Why did the pizza apply for a job?  \n>  Because it wanted to get a *slice* of the action!*\n\nThis joke is a classic example of a **pun**—a play on words that relies on a double meaning. Let’s break it down:\n\n| Part of the joke | Literal meaning | Figurative / pun meaning |\n|------------------|-----------------|--------------------------|\n| **“Pizza”** | A food item made of dough, sauce, cheese, etc. | Personified as a character capable of making decisions. |\n| **“Apply for a job”** | To submit a request to work somewhere. | Indicates the pizza wants to be employed. |\n| **“Slice”** | A portion of a pizza. | Also a metaphor for “a piece” or “a share” of something. |\n| **“Slice of the action”** | A part of an exciting event or activity. | A humorous way of saying “I want to be part of what's happening.” |\n\n### How the pun works\n\n1. **Wordplay on “slice”**  \n   - In the world of pizza, a *slice* is the most common way to serve it.  \n   - In everyday speech, saying you want a *slice of the action* means you want a share of the excitement or a role in something happening.\n\n2. **Anthropomorphism**  \n   - The joke gives the pizza human-like motivations (wanting a job).  \n   - By doing so, it sets up the expectation that the pizza’s desire is a normal human desire, only to twist it with the double meaning of “slice.”\n\n3. **Humor from the unexpected twist**  \n   - The set‑up (“Why did the pizza apply for a job?”) leads the listener to expect a logical, perhaps silly answer (e.g., “Because it needed a dough‑nut”).  \n   - The punchline flips that expectation by using the dual meaning of *slice*, making the pizza’s motivation sound both literal (it wants a slice of pizza) and figurative (it wants a slice of the action).\n\n### Bottom line\n\nThe joke’s humor comes from the clever overlap between a pizza’s literal component (a slice of pizza) and the figurative phrase “slice of the action.” By giving the pizza a job‑seeking motive, the punchline turns a simple culinary term into a playful commentary on wanting to be involved in something exciting."}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-36a0-6534-8002-ed2138e37202'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:38:43.732797+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-2f5e-6a8c-8001-8f7790ca1950'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-2f5e-6a8c-8001-8f7790ca1950'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:38:42.971897+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='8478dad6-986c-66b0-0a32-19c1f220beaa', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': "**Explanation of the joke**\n\n> *Why did the pizza apply for a job?  \n>  Because it wanted to get a *slice* of the action!*\n\nThis joke is a classic example of a **pun**—a play on words that relies on a double meaning. Let’s break it down:\n\n| Part of the joke | Literal meaning | Figurative / pun meaning |\n|------------------|-----------------|--------------------------|\n| **“Pizza”** | A food item made of dough, sauce, cheese, etc. | Personified as a character capable of making decisions. |\n| **“Apply for a job”** | To submit a request to work somewhere. | Indicates the pizza wants to be employed. |\n| **“Slice”** | A portion of a pizza. | Also a metaphor for “a piece” or “a share” of something. |\n| **“Slice of the action”** | A part of an exciting event or activity. | A humorous way of saying “I want to be part of what's happening.” |\n\n### How the pun works\n\n1. **Wordplay on “slice”**  \n   - In the world of pizza, a *slice* is the most common way to serve it.  \n   - In everyday speech, saying you want a *slice of the action* means you want a share of the excitement or a role in something happening.\n\n2. **Anthropomorphism**  \n   - The joke gives the pizza human-like motivations (wanting a job).  \n   - By doing so, it sets up the expectation that the pizza’s desire is a normal human desire, only to twist it with the double meaning of “slice.”\n\n3. **Humor from the unexpected twist**  \n   - The set‑up (“Why did the pizza apply for a job?”) leads the listener to expect a logical, perhaps silly answer (e.g., “Because it needed a dough‑nut”).  \n   - The punchline flips that expectation by using the dual meaning of *slice*, making the pizza’s motivation sound both literal (it wants a slice of pizza) and figurative (it wants a slice of the action).\n\n### Bottom line\n\nThe joke’s humor comes from the clever overlap between a pizza’s literal component (a slice of pizza) and the figurative phrase “slice of the action.” By giving the pizza a job‑seeking motive, the punchline turns a simple culinary term into a playful commentary on wanting to be involved in something exciting."}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄', 'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-aa9e-6be4-8002-b537d6270365'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:29:32.181093+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:29:30.693994+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='581fc5a9-26df-b2fd-f71d-9648c80331a4', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-29T05:29:30.486143+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, tasks=(PregelTask(id='823e43a4-f349-4e77-ff9e-ed4a53352bb1', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-29T05:29:30.485205+00:00', parent_config=None, tasks=(PregelTask(id='7c650d2d-e3b9-8235-dc60-65a875926799', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# # #### Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f0e4775-9a74-6778-8000-a0ba93bce9ef", "checkpoint_ns": ""}}, {'topic':'Burger'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0e478d-d21c-6e92-8001-ede878bbc919'}}

# %% [markdown]
# # ## now we have updated the state with topic as samosa, one more snapshot will be created

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'Burger'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478d-d21c-6e92-8001-ede878bbc919'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:40:20.567405+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='5045ca89-6fb6-7417-b159-6fb478377194', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action! 🍕😄', 'explanation': "**Explanation of the joke**\n\n> *Why did the pizza apply for a job?  \n>  Because it wanted to get a *slice* of the action!*\n\nThis joke is a classic example of a **pun**—a play on words that relies on a double meaning. Let’s break it down:\n\n| Part of the joke | Literal meaning | Figurative / pun meaning |\n|------------------|-----------------|--------------------------|\n| **“Pizza”** | A food item made of dough, sauce, cheese, etc. | Personified as a character capable of making decisions. |\n| **“Apply for a job”** | To submit a request to work somewhere. | Indicates the pizza wants to be employed. |\n| **“Slice”** | A portion of a pizza. | Also a metaphor for “a piece” or “a share” of something. |\n| **“Slice of the action”** | A part of an exciting event or activity. | A humorous way of saying “I want to be part of what's happening.” |\n\n### How the pun works\n\n1. **Wordplay on “slice”**  \n   - In the world of pizza, a *slice* is the most common way to serve it.  \n   - In everyday speech, saying you want a *slice of the action* means you want a share of the excitement or a role in something happening.\n\n2. **Anthropomorphism**  \n   - The joke gives the pizza human-like motivations (wanting a job).  \n   - By doing so, it sets up the expectation that the pizza’s desire is a normal human desire, only to twist it with the double meaning of “slice.”\n\n3. **Humor from the unexpected twist**  \n   - The set‑up (“Why did the pizza apply for a job?”) leads the listener to expect a logical, perhaps silly answer (e.g., “Because it needed a dough‑nut”).  \n   - The punchline flips that expectation by using the dual meaning of *slice*, making the pizza’s motivation sound both literal (it wants a slice of pizza) and figurative (it wants a slice of the action).\n\n### Bottom line\n\nThe joke’s humor comes from the clever overlap between a pizza’s literal component (a slice of pizza) and the figurative phrase “slice of the action.” By giving the pizza a job‑seeking motive, the punchline turns a simple culinary term into a playful commentary on wanting to be involved in something exciting."}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-36a0-6534-8002-ed2138e37202'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:38:43.732797+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-2f5e-6a8c-8001-8f7790ca1950'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-2f5e-6a8c-8001-8f7790ca1950'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:38:42.971897+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='8478dad6-986c-66b0-0a32-19c1f220beaa', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': "**Explanation of the joke**\n\n> *Why did the pizza apply for a job?  \n>  Because it wanted to get a *slice* of the action!*\n\nThis joke is a classic example of a **pun**—a play on words that relies on a double meaning. Let’s break it down:\n\n| Part of the joke | Literal meaning | Figurative / pun meaning |\n|------------------|-----------------|--------------------------|\n| **“Pizza”** | A food item made of dough, sauce, cheese, etc. | Personified as a character capable of making decisions. |\n| **“Apply for a job”** | To submit a request to work somewhere. | Indicates the pizza wants to be employed. |\n| **“Slice”** | A portion of a pizza. | Also a metaphor for “a piece” or “a share” of something. |\n| **“Slice of the action”** | A part of an exciting event or activity. | A humorous way of saying “I want to be part of what's happening.” |\n\n### How the pun works\n\n1. **Wordplay on “slice”**  \n   - In the world of pizza, a *slice* is the most common way to serve it.  \n   - In everyday speech, saying you want a *slice of the action* means you want a share of the excitement or a role in something happening.\n\n2. **Anthropomorphism**  \n   - The joke gives the pizza human-like motivations (wanting a job).  \n   - By doing so, it sets up the expectation that the pizza’s desire is a normal human desire, only to twist it with the double meaning of “slice.”\n\n3. **Humor from the unexpected twist**  \n   - The set‑up (“Why did the pizza apply for a job?”) leads the listener to expect a logical, perhaps silly answer (e.g., “Because it needed a dough‑nut”).  \n   - The punchline flips that expectation by using the dual meaning of *slice*, making the pizza’s motivation sound both literal (it wants a slice of pizza) and figurative (it wants a slice of the action).\n\n### Bottom line\n\nThe joke’s humor comes from the clever overlap between a pizza’s literal component (a slice of pizza) and the figurative phrase “slice of the action.” By giving the pizza a job‑seeking motive, the punchline turns a simple culinary term into a playful commentary on wanting to be involved in something exciting."}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄', 'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-aa9e-6be4-8002-b537d6270365'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:29:32.181093+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:29:30.693994+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='581fc5a9-26df-b2fd-f71d-9648c80331a4', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-29T05:29:30.486143+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, tasks=(PregelTask(id='823e43a4-f349-4e77-ff9e-ed4a53352bb1', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-29T05:29:30.485205+00:00', parent_config=None, tasks=(PregelTask(id='7c650d2d-e3b9-8235-dc60-65a875926799', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# # ## and to execute the workflow from the updated state (samosa) we need to pass the checkpoint id of samosa snapshot

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f0e478d-d21c-6e92-8001-ede878bbc919"}})
# Out:
# {'topic': 'Burger',
#  'joke': 'Why did the burger go to therapy?\n\nBecause it had too many “lettuce” issues and couldn’t stop feeling “meat” of its own problem!',
#  'explanation': '**Why the joke works – a quick breakdown**\n\n| Element | What’s happening | Why it’s funny |\n|---------|------------------|----------------|\n| **The set‑up** | “Why did the burger go to therapy?” | It sets up an absurd premise: a burger, a food item, is a person with psychological problems. The reader instantly knows we’re in the realm of a pun or a play on words. |\n| **“Too many ‘lettuce’ issues”** | *Lettuce* is a vegetable that’s a key ingredient in most burgers. The joke replaces the ordinary “lettuce” with the phrase “lettuce” (pronounced *let‑us*). So the burger is literally “letting us” (lettuce) issues – it can’t stop holding onto them. | The pun works on two levels: the literal ingredient and the phrase “let us.” It’s a classic *word‑play* joke, where a homophone (lettuce/let us) creates a double meaning. |\n| **“Couldn’t stop feeling ‘meat’ of its own problem!”** | *Meat* is the core of a burger, and the joke turns it into “meet” (the verb). The burger is “meeting” the problem, i.e., confronting it, but it’s stuck in the “meat” (core) of the issue. | Again, a homophone: *meat* (food) ↔ *meet* (to encounter). It’s a twist on the idea that the burger is stuck in the heart (meat) of its problems. |\n| **Anthropomorphism** | The burger is given human emotions (“issues,” “therapy,” “feeling”). | Giving a non‑human object human feelings is a classic comedic device. It makes the punchline feel like a joke about a person, but the punchline is still a pun. |\n| **Therapy as a mental‑health context** | Therapy is a place where people talk about their problems. | The burger “going to therapy” is absurd, because burgers don’t have minds. The absurdity adds to the humor. |\n| **The payoff** | The joke ends with a double pun: “lettuce issues” and “meat of its own problem.” | The two puns land in a single line, giving a quick, satisfying twist. The audience gets a “aha” moment when they realize the words are playing on themselves. |\n\n### Bottom line\n\nThe joke is a classic *pun‑based* joke that relies on the homophones **lettuce / let us** and **meat / meet**. It anthropomorphizes a burger, places it in a human context (therapy), and then delivers the punchline by turning ordinary burger ingredients into expressions of psychological distress. The absurdity of a burger needing therapy, combined with the clever wordplay, makes the punchline unexpected and amusing.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'Burger', 'joke': 'Why did the burger go to therapy?\n\nBecause it had too many “lettuce” issues and couldn’t stop feeling “meat” of its own problem!', 'explanation': '**Why the joke works – a quick breakdown**\n\n| Element | What’s happening | Why it’s funny |\n|---------|------------------|----------------|\n| **The set‑up** | “Why did the burger go to therapy?” | It sets up an absurd premise: a burger, a food item, is a person with psychological problems. The reader instantly knows we’re in the realm of a pun or a play on words. |\n| **“Too many ‘lettuce’ issues”** | *Lettuce* is a vegetable that’s a key ingredient in most burgers. The joke replaces the ordinary “lettuce” with the phrase “lettuce” (pronounced *let‑us*). So the burger is literally “letting us” (lettuce) issues – it can’t stop holding onto them. | The pun works on two levels: the literal ingredient and the phrase “let us.” It’s a classic *word‑play* joke, where a homophone (lettuce/let us) creates a double meaning. |\n| **“Couldn’t stop feeling ‘meat’ of its own problem!”** | *Meat* is the core of a burger, and the joke turns it into “meet” (the verb). The burger is “meeting” the problem, i.e., confronting it, but it’s stuck in the “meat” (core) of the issue. | Again, a homophone: *meat* (food) ↔ *meet* (to encounter). It’s a twist on the idea that the burger is stuck in the heart (meat) of its problems. |\n| **Anthropomorphism** | The burger is given human emotions (“issues,” “therapy,” “feeling”). | Giving a non‑human object human feelings is a classic comedic device. It makes the punchline feel like a joke about a person, but the punchline is still a pun. |\n| **Therapy as a mental‑health context** | Therapy is a place where people talk about their problems. | The burger “going to therapy” is absurd, because burgers don’t have minds. The absurdity adds to the humor. |\n| **The payoff** | The joke ends with a double pun: “lettuce issues” and “meat of its own problem.” | The two puns land in a single line, giving a quick, satisfying twist. The audience gets a “aha” moment when they realize the words are playing on themselves. |\n\n### Bottom line\n\nThe joke is a classic *pun‑based* joke that relies on the homophones **lettuce / let us** and **meat / meet**. It anthropomorphizes a burger, places it in a human context (therapy), and then delivers the punchline by turning ordinary burger ingredients into expressions of psychological distress. The absurdity of a burger needing therapy, combined with the clever wordplay, makes the punchline unexpected and amusing.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4792-70c3-6d76-8003-e6b5d05234b1'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2025-12-29T05:42:24.577457+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4792-655e-6b5c-8002-5cef1c6a829c'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Burger', 'joke': 'Why did the burger go to therapy?\n\nBecause it had too many “lettuce” issues and couldn’t stop feeling “meat” of its own problem!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4792-655e-6b5c-8002-5cef1c6a829c'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:42:23.382597+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478d-d21c-6e92-8001-ede878bbc919'}}, tasks=(PregelTask(id='c82cd99f-d4b4-7dd3-7c20-479ba783acbf', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**Why the joke works – a quick breakdown**\n\n| Element | What’s happening | Why it’s funny |\n|---------|------------------|----------------|\n| **The set‑up** | “Why did the burger go to therapy?” | It sets up an absurd premise: a burger, a food item, is a person with psychological problems. The reader instantly knows we’re in the realm of a pun or a play on words. |\n| **“Too many ‘lettuce’ issues”** | *Lettuce* is a vegetable that’s a key ingredient in most burgers. The joke replaces the ordinary “lettuce” with the phrase “lettuce” (pronounced *let‑us*). So the burger is literally “letting us” (lettuce) issues – it can’t stop holding onto them. | The pun works on two levels: the literal ingredient and the phrase “let us.” It’s a classic *word‑play* joke, where a homophone (lettuce/let us) creates a double meaning. |\n| **“Couldn’t stop feeling ‘meat’ of its own problem!”** | *Meat* is the core of a burger, and the joke turns it into “meet” (the verb). The burger is “meeting” the problem, i.e., confronting it, but it’s stuck in the “meat” (core) of the issue. | Again, a homophone: *meat* (food) ↔ *meet* (to encounter). It’s a twist on the idea that the burger is stuck in the heart (meat) of its problems. |\n| **Anthropomorphism** | The burger is given human emotions (“issues,” “therapy,” “feeling”). | Giving a non‑human object human feelings is a classic comedic device. It makes the punchline feel like a joke about a person, but the punchline is still a pun. |\n| **Therapy as a mental‑health context** | Therapy is a place where people talk about their problems. | The burger “going to therapy” is absurd, because burgers don’t have minds. The absurdity adds to the humor. |\n| **The payoff** | The joke ends with a double pun: “lettuce issues” and “meat of its own problem.” | The two puns land in a single line, giving a quick, satisfying twist. The audience gets a “aha” moment when they realize the words are playing on themselves. |\n\n### Bottom line\n\nThe joke is a classic *pun‑based* joke that relies on the homophones **lettuce / let us** and **meat / meet**. It anthropomorphizes a burger, places it in a human context (therapy), and then delivers the punchline by turning ordinary burger ingredients into expressions of psychological distress. The absurdity of a burger needing therapy, combined with the clever wordplay, makes the punchline unexpected and amusing.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Burger'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478d-d21c-6e92-8001-ede878bbc919'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:40:20.567405+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='5045ca89-6fb6-7417-b159-6fb478377194', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the burger go to therapy?\n\nBecause it had too many “lettuce” issues and couldn’t stop feeling “meat” of its own problem!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action! 🍕😄', 'explanation': "**Explanation of the joke**\n\n> *Why did the pizza apply for a job?  \n>  Because it wanted to get a *slice* of the action!*\n\nThis joke is a classic example of a **pun**—a play on words that relies on a double meaning. Let’s break it down:\n\n| Part of the joke | Literal meaning | Figurative / pun meaning |\n|------------------|-----------------|--------------------------|\n| **“Pizza”** | A food item made of dough, sauce, cheese, etc. | Personified as a character capable of making decisions. |\n| **“Apply for a job”** | To submit a request to work somewhere. | Indicates the pizza wants to be employed. |\n| **“Slice”** | A portion of a pizza. | Also a metaphor for “a piece” or “a share” of something. |\n| **“Slice of the action”** | A part of an exciting event or activity. | A humorous way of saying “I want to be part of what's happening.” |\n\n### How the pun works\n\n1. **Wordplay on “slice”**  \n   - In the world of pizza, a *slice* is the most common way to serve it.  \n   - In everyday speech, saying you want a *slice of the action* means you want a share of the excitement or a role in something happening.\n\n2. **Anthropomorphism**  \n   - The joke gives the pizza human-like motivations (wanting a job).  \n   - By doing so, it sets up the expectation that the pizza’s desire is a normal human desire, only to twist it with the double meaning of “slice.”\n\n3. **Humor from the unexpected twist**  \n   - The set‑up (“Why did the pizza apply for a job?”) leads the listener to expect a logical, perhaps silly answer (e.g., “Because it needed a dough‑nut”).  \n   - The punchline flips that expectation by using the dual meaning of *slice*, making the pizza’s motivation sound both literal (it wants a slice of pizza) and figurative (it wants a slice of the action).\n\n### Bottom line\n\nThe joke’s humor comes from the clever overlap between a pizza’s literal component (a slice of pizza) and the figurative phrase “slice of the action.” By giving the pizza a job‑seeking motive, the punchline turns a simple culinary term into a playful commentary on wanting to be involved in something exciting."}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-36a0-6534-8002-ed2138e37202'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:38:43.732797+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-2f5e-6a8c-8001-8f7790ca1950'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e478a-2f5e-6a8c-8001-8f7790ca1950'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:38:42.971897+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='8478dad6-986c-66b0-0a32-19c1f220beaa', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': "**Explanation of the joke**\n\n> *Why did the pizza apply for a job?  \n>  Because it wanted to get a *slice* of the action!*\n\nThis joke is a classic example of a **pun**—a play on words that relies on a double meaning. Let’s break it down:\n\n| Part of the joke | Literal meaning | Figurative / pun meaning |\n|------------------|-----------------|--------------------------|\n| **“Pizza”** | A food item made of dough, sauce, cheese, etc. | Personified as a character capable of making decisions. |\n| **“Apply for a job”** | To submit a request to work somewhere. | Indicates the pizza wants to be employed. |\n| **“Slice”** | A portion of a pizza. | Also a metaphor for “a piece” or “a share” of something. |\n| **“Slice of the action”** | A part of an exciting event or activity. | A humorous way of saying “I want to be part of what's happening.” |\n\n### How the pun works\n\n1. **Wordplay on “slice”**  \n   - In the world of pizza, a *slice* is the most common way to serve it.  \n   - In everyday speech, saying you want a *slice of the action* means you want a share of the excitement or a role in something happening.\n\n2. **Anthropomorphism**  \n   - The joke gives the pizza human-like motivations (wanting a job).  \n   - By doing so, it sets up the expectation that the pizza’s desire is a normal human desire, only to twist it with the double meaning of “slice.”\n\n3. **Humor from the unexpected twist**  \n   - The set‑up (“Why did the pizza apply for a job?”) leads the listener to expect a logical, perhaps silly answer (e.g., “Because it needed a dough‑nut”).  \n   - The punchline flips that expectation by using the dual meaning of *slice*, making the pizza’s motivation sound both literal (it wants a slice of pizza) and figurative (it wants a slice of the action).\n\n### Bottom line\n\nThe joke’s humor comes from the clever overlap between a pizza’s literal component (a slice of pizza) and the figurative phrase “slice of the action.” By giving the pizza a job‑seeking motive, the punchline turns a simple culinary term into a playful commentary on wanting to be involved in something exciting."}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄', 'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-aa9e-6be4-8002-b537d6270365'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-29T05:29:32.181093+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9c6f-6f00-8001-276b1f37cb27'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-29T05:29:30.693994+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, tasks=(PregelTask(id='581fc5a9-26df-b2fd-f71d-9648c80331a4', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**Why the joke works – a quick “crust”‑level explanation**\n\n| Element | What it does | Why it’s funny |\n|---------|--------------|----------------|\n| **Anthropomorphism** | The pizza is treated as a person who can “feel” and go to therapy. | It’s absurd to imagine a slice of dough having emotions, so the setup already feels like a playful exaggeration. |\n| **Wordplay on “crust”** | *“Crusted out”* sounds like the phrase *“crushed out”* (meaning exhausted or overwhelmed) but literally refers to the pizza’s outer edge. | The double meaning lets us think of both a tired person and a literal crust that’s become hard or burnt. |\n| **Made‑up verb “cheddared”** | A playful mash‑up of *cheddar* (the cheese) and a verb ending, implying the pizza is “cheddared” (cheddar‑filled or “chewed up”) under pressure. | It’s a goofy, on‑the‑nose pun that turns a cheese‑related adjective into an action, while also hinting at the pressure that makes the cheese stretch or melt. |\n| **Phrase “under pressure”** | A common idiom for stress, but it also describes the physical pressure a pizza feels from the oven heat. | The double meaning reinforces the idea that the pizza’s “cheddared” state is both emotional and literal. |\n| **Punctuation and emoji** | The question mark, exclamation, and pizza emoji punctuate the joke’s playful tone. | Visual cues help the reader quickly recognize the joke’s light‑hearted, pun‑heavy nature. |\n\n**Putting it all together**\n\nThe joke starts with a classic “Why did ___ go to therapy?” set‑up, which primes the listener for a punchline that usually involves a pun or a play on words. The answer replaces the usual “animal” or “object” with a *pizza*, instantly making it a food‑centric joke.\n\n- **“Crusted out”** – the pizza feels “crusted out” (crushed out) because its crust is over‑baked or worn thin.  \n- **“Cheddared under pressure”** – the cheese is “cheddared” (cheddar‑filled, stretched, or even “chewed” in a goofy sense) while the oven’s pressure forces it to melt.\n\nThe humor comes from the absurdity of a pizza having emotional baggage, the clever double meanings of “crust” and “cheddared,” and the way the punchline mirrors the literal process of baking a pizza while also sounding like a human coping strategy. The emoji caps it off, reminding us that this is all in good, cheesy fun.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a74-6778-8000-a0ba93bce9ef'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-29T05:29:30.486143+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, tasks=(PregelTask(id='823e43a4-f349-4e77-ff9e-ed4a53352bb1', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to therapy?  \n\nBecause it felt *crust*ed out and *cheddared* under pressure! 🍕😄'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e4775-9a72-628e-bfff-692de1ccddbb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-29T05:29:30.485205+00:00', parent_config=None, tasks=(PregelTask(id='7c650d2d-e3b9-8235-dc60-65a875926799', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# # ### Fault Tolerance kind of similar as human in the loop (In HITL we do it perpupose fully using langraph interrupt)

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str
    step3: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(10)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"step3": "done"}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
graph

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")

# %%
graph.get_state({"configurable": {"thread_id": 'thread-1'}})

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
